# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import pickle
import numpy as np
import pandas as pd

lemmatizer = WordNetLemmatizer()

'''
polarity 0 = negative. 2 = neutral. 4 = positive.
id
date
query
user
tweet
'''
# Out:
# '\npolarity 0 = negative. 2 = neutral. 4 = positive.\nid\ndate\nquery\nuser\ntweet\n'

# %%
def init_process(fin,fout): # output lots of "[0,1]:::tweet content", unless the tweet is neutral
    outfile = open(fout,'a') # append to end of fout file
    with open(fin, buffering=200000, encoding='latin-1') as f: # 200KB buffer
        try:
            for line in f:
                line = line.replace('"','')
                initial_polarity = line.split(',')[0]
                if initial_polarity == '0':
                    initial_polarity = [1,0]
                elif initial_polarity == '4': 
                    initial_polarity = [0,1]
                # the code doesn't deal with neutral (2) tweets?

                tweet = line.split(',')[-1]
                outline = str(initial_polarity)+':::'+tweet
                outfile.write(outline)
        except Exception as e:
            print(str(e))
    outfile.close()

# %%
init_process('./stanford_sentiment_tweets/training.1600000.processed.noemoticon.csv','train_set.csv')
init_process('./stanford_sentiment_tweets/testdata.manual.2009.06.14.csv','test_set.csv')

# %% [markdown]
# #### test_set contains more negative sentiment data than positive, roughly 3:1

# %%
def create_lexicon(fin): # lexicon will look like this: ['words', 'order', 'lexicon', 'in', 'random']
    lexicon = []
    with open(fin, 'r', buffering=100000, encoding='latin-1') as f:
        try:
            counter = 1
            for line in f: # sample 1 line for every 2500 lines, maybe using linecache module would be better?
                counter += 1
                if (counter%2500) is 0:
                    content = ''
                    tweet = line.split(':::')[1]
                    content += ' '+tweet
                    words = word_tokenize(content) # ['this','is','a','tweet']
                    words = [lemmatizer.lemmatize(i) for i in words]
                    lexicon = list(set(lexicon + words)) # words already in lexicon are not repeatedly added
                    print('after line', counter, 'lexicon now has', len(lexicon), ' words')
                    print('content is ', content)

        except Exception as e:
            print(str(e))

    with open('lexicon.pickle','wb') as f: # write in binary mode
        pickle.dump(lexicon,f)

# %%
create_lexicon('train_set.csv') # TODO: the tutorial code is wrong, repeats training data 3 times...
# Out:
# after line 2500 lexicon now has 26  words
# content is   @Splont   I have a meeting all morning today if that makes you feel better ? Though I finish tomorrow until next weds to make you hate me!
#
# after line 5000 lexicon now has 32  words
# content is   trying to keep my eyes open..damn baking
#
# after line 7500 lexicon now has 41  words
# content is   ahh Juicy fruit gum lose their flavour sooo quickly
#
# after line 10000 lexicon now has 63  words
# content is   CRAP! After looking when I last tweeted... WHY AM I UP SO EARLY. It's 10! I shouldn't be up until like... 12.
#
# after line 12500 lexicon now has 85  words
# content is   @diannabee it's not as painful as b4...but that ugly bruise is still there   and Idk how to do that @ thing on my phone b/c i'm dumb
#
# after line 15000 lexicon now has 89  words
# content is   really miss talking to missy
#
# after line 17500 lexicon now has 91  words
# content is   missing my boyfriend
#
# after line 20000 lexicon now has 108  words
# content is   i hv to READ the whole book of personality types before i can embark on my typing!!  no fun for my SUNDAY  warrrrhhh
#
# after line 22500 lexicon now has 113  words
# content is   so tired. back to school 2moz
#
# after line 25000 lexicon now has 120  words
# content is   night all. love yas. hahahahahah btw... vodka is evil
#
# after line 27500 lexicon now has 128  words
# content is    today is soooo effing horrible because its raining  me no like like rain :p
#
# after line 30000 lexicon now has 141  words
# content is    but Im scared to walk dwn the hall. Please check for that mouse..Im freaking out! Turn the light on 4 me
#
# after line 32500 lexicon now has 159  words
# content is   21 days to pull this shizz out of the bag! anyone got a top hat? more likely to pull ghandi outta it than pass these exams
#
# after line 35000 lexicon now has 173  words
# content is   really really really wants to enroll in online design institute. now if only there was an angel investor to chip in for tuition
#
# after line 37500 lexicon now has 177  words
# content is   can't find megan on twitter
#
# after line 40000 lexicon now has 185  words
# content is   Anyway... Not particularly looking foreward to labs today... I wan't to gig.  #fb
#
# after line 42500 lexicon now has 198  words
# content is   @empressjazzy1 i really like 'him' &amp; he really likes me &amp; we're driftin apart .. &amp; it suckss
#
# after line 45000 lexicon now has 212  words
# content is   @mistressmia hey babe! Missed u at #rockplat  yes back in aus June august nov. Will u be around?
#
# after line 47500 lexicon now has 224  words
# content is   @jaygee35 sounds lovely but probably a bit exe for just me on my own  many tx for recommendations though
#
# after line 50000 lexicon now has 240  words
# content is   I WANT ANOTHER DAY OFF!!!!  To much Sh#t to do today. Got a &quot;new/used&quot; futon!! and is going to get a &quot;new/used&quot; dining table!!
#
# after line 52500 lexicon now has 252  words
# content is   I`m listen music of the JONAS!! I Love the JONAS BROTHERS!!.. What a pity that I canÃ¯Â¿Â½t go to his concert!!
#
# after line 55000 lexicon now has 265  words
# content is   I'm closer where I started....chasing after you........I'm fallin even more in love with you* holding on to all I've held on to
#
# after line 57500 lexicon now has 266  words
# content is    Pao.
#
# after line 60000 lexicon now has 268  words
# content is   I'm not in the mood of studing!!!!!!!!! but i have to
#
# after line 62500 lexicon now has 279  words
# content is   fucking shit. Big day ahead of us with boozle. Can't even see no doubt or taking back Sunday
#
# after line 65000 lexicon now has 283  words
# content is   I'm annoyed I didn't get to go to the falconry fair
#
# after line 67500 lexicon now has 290  words
# content is   @the__click5 thaaaanks!!! but what if i live in the philippines and i can't get the free stuff?
#
# after line 70000 lexicon now has 298  words
# content is   I will be so much happier when I don't have to read about STDs anymore   It's such a Debbie-Downer
#
# after line 72500 lexicon now has 305  words
# content is   @DannyGirlAlways Eventhough in his first scene Donnie got punched in the face
#
# after line 75000 lexicon now has 320  words
# content is   Boohoo to my teams (miami and chicago) being eliminated over the weekend  BUT that tko by pacman was insaaaane!
#
# after line 77500 lexicon now has 328  words
# content is   Crap... I'm not a big JJ Abrams fan but all this hype makes me want to see Star Trek
#
# after line 80000 lexicon now has 335  words
# content is   Plans of going to the club have been dashed. Now I'm just all dressed up for coach's.
#
# after line 82500 lexicon now has 344  words
# content is   @DrMegan81 Yeah I saw that one last night. Sad  Him even attempting it though was very commendable!
#
# after line 85000 lexicon now has 355  words
# content is    I have a bookshelf there on my desk. No room.  Mac Mini is also 2000 bucks cheaper heh.
#
# after line 87500 lexicon now has 357  words
# content is    another Monday
#
# after line 90000 lexicon now has 360  words
# content is   @karolein_  hope you're not that sad
#
# after line 92500 lexicon now has 373  words
# content is   @rosadelaD the kids reading to their mamas was cute and the lil girl singing.. Was miles at urs? cuz he wasn't at mines
#
# after line 95000 lexicon now has 387  words
# content is   #twiparty I guess got frozen up. You guys were great! I'm going to pause at ballet studio bc i miss your comments   #rpattz
#
# after line 97500 lexicon now has 398  words
# content is   Going to force myself to sleep ... I rather work on some art ...  .... but i know if I start now I'll be up all night
#
# after line 100000 lexicon now has 401  words
# content is   @flossa  *offers you pepto*
#
# after line 102500 lexicon now has 411  words
# content is   @martinpribble I remember stumbling on an awesome knot site but can't find it now  if anyone else knows one let us both know! #climb
#
# after line 105000 lexicon now has 417  words
# content is    but I gotta get my homework done *Idontwannaidontwannaidontwanna!!!!!!* but I will anyway
#
# after line 107500 lexicon now has 424  words
# content is    too. now i'm just pathetic and watching disney movies all alone wishing i was in love.
#
# after line 110000 lexicon now has 428  words
# content is    I wanna upload itt.
#
# after line 112500 lexicon now has 437  words
# content is   @ohappleda  People hate it?  I love it a lot! WE ARE THE TRUE FANS OBVIOUSLY.
#
# after line 115000 lexicon now has 447  words
# content is   I'm beginning to regret throwing out 99% of my closet. Society still demands you wear pants.
#
# after line 117500 lexicon now has 449  words
# content is   not feeling well...
#
# after line 120000 lexicon now has 452  words
# content is   how do you twitter...i thot twittering was easy
#
# after line 122500 lexicon now has 459  words
# content is   just sobbed for a good 5 minutes after watching the ending of prison break
#
# after line 125000 lexicon now has 464  words
# content is   Heading out with the dogs. Looks cold ouside
#
# after line 127500 lexicon now has 465  words
# content is   still really sick ... no school for me
#
# after line 130000 lexicon now has 467  words
# content is   is missing her family
#
# after line 132500 lexicon now has 469  words
# content is    and the tops of my ears. Geez.
#
# after line 135000 lexicon now has 479  words
# content is   Just came back from exercise. It seems I lost my stamina due to a week of inactivity.
#
# after line 137500 lexicon now has 489  words
# content is   Why must it be cloudy? I can't get up early without the sun raping me  (although I did wake up at 6:30)
#
# after line 140000 lexicon now has 495  words
# content is   thinks her email must be broken as no new messages for HOURS....
#
# after line 142500 lexicon now has 499  words
# content is   Test Today  Berry hard..gggrrr
#
# after line 145000 lexicon now has 506  words
# content is   Is quietly confident about visa situation but resigned to missing the Berg next week.
#
# after line 147500 lexicon now has 513  words
# content is   Making the benjamins... Only small amount of benjamins bc my job is dookie...
#
# after line 150000 lexicon now has 527  words
# content is   tidak menemukan cd album 'off the beaten path' nya dave koz di disc tarra citraland
#
# after line 152500 lexicon now has 531  words
# content is   @JJaeng oh gosh that just suckkkkks for you
#
# after line 155000 lexicon now has 535  words
# content is   TIRED!! Majorly Bored of revision!
#
# after line 157500 lexicon now has 539  words
# content is   Ugh slow week! Come on already
#
# after line 160000 lexicon now has 547  words
# content is   Just one more day in San Jose and then we're officially on vacation. If only I didn't have to get through subbing first
#
# after line 162500 lexicon now has 555  words
# content is   hmz... second most popular page on this governmental site is the 404 page... fail
#
# after line 165000 lexicon now has 559  words
# content is   Glad to see the sun out in Dublin after a great week in London. Back to work
#
# after line 167500 lexicon now has 561  words
# content is   I hope amy is okai
#
# after line 170000 lexicon now has 565  words
# content is   #twitterfails fucking hard right now...this is annoying
#
# after line 172500 lexicon now has 570  words
# content is    I'm Vegan too!&quot;(insert hot wink)too young
#
# after line 175000 lexicon now has 579  words
# content is   @Livvixo go for the 1 that you want to go to most? my bro had to switch when he did his 1st time  it's www.direct.gov.uk/studentfinance :]
#
# after line 177500 lexicon now has 582  words
# content is   @TheKellanLutz OMG i want to go too!  hahaha
#
# after line 180000 lexicon now has 587  words
# content is   And other girls come over... And my boyfriend forgets that I'm here
#
# after line 182500 lexicon now has 593  words
# content is    promise..have fun!! Don't hurt them youngns lmao
#
# after line 185000 lexicon now has 596  words
# content is   @VizardKid [tear]
#
# after line 187500 lexicon now has 599  words
# content is   I Miss My Family
#
# after line 190000 lexicon now has 606  words
# content is   @ice89 Hi Hugssssssssss to you We can not use myspace there is a virius there
#
# after line 192500 lexicon now has 610  words
# content is   @PinksTwitFans I no and im getting made
#
# after line 195000 lexicon now has 620  words
# content is   Im so tired. I finished most of my homework. i couldnt work on my gourd today  tommorrow ill be doing red shield appeal with memoo~~~
#
# after line 197500 lexicon now has 623  words
# content is   hungoverrrr. it's gonna be a long day at work
#
# after line 200000 lexicon now has 627  words
# content is   my baby boy is wearing big boy underwear
#
# after line 202500 lexicon now has 629  words
# content is    but I guess she's going camping now.
#
# after line 205000 lexicon now has 631  words
# content is   Twitturds must not like my new picture
#
# after line 207500 lexicon now has 640  words
# content is   Very jealous of @nmyers89  who is having a domino pizza... Tuna for Josh
#
# after line 210000 lexicon now has 643  words
# content is   @Hollymark aw  what happened
#
# after line 212500 lexicon now has 647  words
# content is   @lamecasper   I really wish I could come but i'm out of town this weekend.
#
# after line 215000 lexicon now has 650  words
# content is   Having a LOTR marathon...on my own
#
# after line 217500 lexicon now has 658  words
# content is    and i needed something to do with my hands. while writing this my cup blew over and is now dirty
#
# after line 220000 lexicon now has 673  words
# content is   @AAirwaves Just realized I made a mistake in booking flights for our honeymoon.  Still 4+ months away. Any chance AA could cut us a break?
#
# after line 222500 lexicon now has 683  words
# content is   @tommcfly The show today was totally KICK ASS! Loved it! Hope you guys come back to Rio soon
#
# after line 225000 lexicon now has 688  words
# content is   is depressed. So many turnovers  #hawthorn #afl
#
# after line 227500 lexicon now has 693  words
# content is   Worst night of my life  @Lindsey3415 and @Im_Always_Right I have to call you guys soon
#
# after line 230000 lexicon now has 697  words
# content is   @stacideshazer it looks like a lot of the photos came out mediocre
#
# after line 232500 lexicon now has 699  words
# content is    did Everton win??
#
# after line 235000 lexicon now has 705  words
# content is   @djohanna wow. shweeet. i hope he'll be ok. i'm so worried about him.
#
# after line 237500 lexicon now has 713  words
# content is   No one is tweeting much today...suppose they're all at the beach  when I'm stuck inside revising ...bad times
#
# after line 240000 lexicon now has 716  words
# content is   @AlexAllTimeLow i need colors for you!!!
#
# after line 242500 lexicon now has 720  words
# content is   Going to hang out with my mammy..soo shreepy I misses my bf
#
# after line 245000 lexicon now has 721  words
# content is    I miss home
#
# after line 247500 lexicon now has 724  words
# content is   @CJHatter location to the internet as well
#
# after line 250000 lexicon now has 727  words
# content is   @BlazinSquadNEws oh no  i`m sorry for you. i hope you get better soon!
#
# after line 252500 lexicon now has 732  words
# content is   Sitting in a car while my brother is at his friends house
#
# after line 255000 lexicon now has 741  words
# content is   @Oreosandcheese Hell yea! He totally burns me lol! I heard its awesom but I not got OTM
#
# after line 257500 lexicon now has 743  words
# content is   I cannot sleep don't know whts wrong with me
#
# after line 260000 lexicon now has 747  words
# content is   really could go for a mocha/chai tea latte right now..
#
# after line 262500 lexicon now has 754  words
# content is   when are the beat freaks gonna be in guam? just curious.. it's not like im gonna go.. i cantt
#
# after line 265000 lexicon now has 757  words
# content is   Getting ready for school already...NOOOOO
#
# after line 267500 lexicon now has 762  words
# content is   is starting to take videos for FYP  So scary.
#
# after line 270000 lexicon now has 765  words
# content is   @ work early as hell..so tired of bein here dis early
#
# after line 272500 lexicon now has 767  words
# content is    I'm still so tired....I didn't do any of my homework.
#
# after line 275000 lexicon now has 771  words
# content is   @SKINTHIWATT I think it is a combination of things. It's not right though. Shouldn't happen. very sad
#
# after line 277500 lexicon now has 776  words
# content is    @Emmmaa___ has been on twitter for agesss! its extremely quiet without her
#
# after line 280000 lexicon now has 776  words
# content is    you hate me remember?
#
# after line 282500 lexicon now has 777  words
# content is   Laundry time
#
# after line 285000 lexicon now has 781  words
# content is   @dietcokebottle whoops.  did the second officer die?
#
# after line 287500 lexicon now has 782  words
# content is   I so wish it was tomorrow already...I need to know where my Marvin is
#
# after line 290000 lexicon now has 786  words
# content is    there's never any family time anymore  Feeling = Sad/Upset
#
# after line 292500 lexicon now has 793  words
# content is   @nessanguyen my first batch died from overheating. Only 1 survived  but i'm growing as second batch...hope I have better luck!
#
# after line 295000 lexicon now has 797  words
# content is   @letz_ dont't hate me ._.    imo you is.
#
# after line 297500 lexicon now has 799  words
# content is    lyric block.
#
# after line 300000 lexicon now has 805  words
# content is    humidity of Florida in just 6 days    doooooon't goooooooooo CASEY!
#
# after line 302500 lexicon now has 808  words
# content is   @Leanne416 what kind is she? I cant see from my phone
#
# after line 305000 lexicon now has 812  words
# content is   JFC look at the time and I'm not even close to being done  FUCKITY FUCK FUCK!!!
#
# after line 307500 lexicon now has 815  words
# content is    not looking forward to saying goodbye!
#
# after line 310000 lexicon now has 818  words
# content is   @Leafybear  just as it got dark so no garden
#
# after line 312500 lexicon now has 820  words
# content is   @_ralph uhh I know how you feel
#
# after line 315000 lexicon now has 825  words
# content is   @Tatterededges and then there's ppl like my hubby who don't have sick leave or holidays
#
# after line 317500 lexicon now has 828  words
# content is   @caitlinhosking aww i wish i was there  hope you are having funx
#
# after line 320000 lexicon now has 830  words
# content is   finally get to use internet after 5 days. internet here is way too slow
#
# after line 322500 lexicon now has 833  words
# content is   i've ate 2 much chocolate
#
# after line 325000 lexicon now has 834  words
# content is   is it really goodbye NDGM?
#
# after line 327500 lexicon now has 844  words
# content is   Because I planned this retreat! Gym tomorrow the abs are sick and work  bed early as hell cuz I got a 5 mile run at 5 am! Yikes!!!
#
# after line 330000 lexicon now has 848  words
# content is   is sad that Jocelyn is gone til the 16th.
#
# after line 332500 lexicon now has 852  words
# content is   really needs to invest in an umbrella. Now feels like a soggy biscuit
#
# after line 335000 lexicon now has 855  words
# content is    any actual good news lately??
#
# after line 337500 lexicon now has 859  words
# content is   lowbatt  off.. http://plurk.com/p/y2klf
#
# after line 340000 lexicon now has 861  words
# content is    i see virus alert
#
# after line 342500 lexicon now has 864  words
# content is    food n attention!
#
# after line 345000 lexicon now has 870  words
# content is    even although i planned to get up at 9! Had a weird dream...never found out how i escaped though
#
# after line 347500 lexicon now has 879  words
# content is   I'm going to be super productive if the Reflective message board stays down all day  Need moar boards to lurk!
#
# after line 350000 lexicon now has 881  words
# content is   @mileycyrus i wanna go to ur concert! but i can't... hope to see you SOMEDAY.....
#
# after line 352500 lexicon now has 892  words
# content is   I was just typing my blog then my computer restarted. And there's no retrieved stuff whatesoever. IMMA CRY NOW  Joke. Too lazy to type...
#
# after line 355000 lexicon now has 895  words
# content is   Damn cant get on da web
#
# after line 357500 lexicon now has 903  words
# content is   Juliet has to go back to the hospital in the morning for blood work again.  Today was so awful.. She hated it.. I feel so bad
#
# after line 360000 lexicon now has 906  words
# content is   my phone is dead. i feel a little lost and alone.  codependency to my phone. not so good.
#
# after line 362500 lexicon now has 912  words
# content is   @Medicci oh no thats ridiculous that he has to wait and worry about what may or may not happen.
#
# after line 365000 lexicon now has 915  words
# content is   @xxxmariaxxxx hope soooo......... but i doubt it im not that lucky enough!!!!!
#
# after line 367500 lexicon now has 916  words
# content is   @EliteByDesign I know right.
#
# after line 370000 lexicon now has 924  words
# content is   kjfkjdfjdgj fuck you mcfly.. try touring in Canada.. not just everywhere else in the world.
#
# after line 372500 lexicon now has 937  words
# content is   i just read this comment on worldstarhiphop  &quot;NEWS JUST IN: CHOPPERS SUIT BEEFIN WITH SPECTACULARS PANTIES&quot; *hangs head* i laffed a lil
#
# after line 375000 lexicon now has 941  words
# content is   I take credit for @cnords staying in. Sorry
#
# after line 377500 lexicon now has 945  words
# content is   cant believe im going to bed this early on the weekend  ughh... work is ruining my life!!!!!!!!!!!!! hahaha... :-/
#
# after line 380000 lexicon now has 947  words
# content is    ty for the info.  I feels so bad for her.
#
# after line 382500 lexicon now has 948  words
# content is    but got so much work to do this weekend... and it's my birthday
#
# after line 385000 lexicon now has 952  words
# content is   is being a Jimmy-no-mates by seeing Terminator Salvation on his own
#
# after line 387500 lexicon now has 956  words
# content is   @MsDelaney ahhh damn! I'll have to get my stalk on another day then!!
#
# after line 390000 lexicon now has 964  words
# content is   Doing laundry 'coz my fingers hurt - I haven't played guitar in a while and have to re-callous my fingers.
#
# after line 392500 lexicon now has 966  words
# content is   wow i got like.. an hour of sleep
#
# after line 395000 lexicon now has 972  words
# content is   My Pyrograph is broken. No more wood burnings until I've managed to find a new one...and I have so many orders to complete!
#
# after line 397500 lexicon now has 980  words
# content is   Poor strategy by Dhoni.. he should have come at no.4 or 5.. he wasted the middle overs with Gambhir
#
# after line 400000 lexicon now has 982  words
# content is   Wishing I was at OOC right now  didn't get to see it at all
#
# after line 402500 lexicon now has 989  words
# content is   is coming back from Cherry Creek Reservoir!!! Hella cold and wet.  warm me up??
#
# after line 405000 lexicon now has 990  words
# content is   come back to me toywatch
#
# after line 407500 lexicon now has 993  words
# content is    I was planning on stalking them around bethelem.
#
# after line 410000 lexicon now has 996  words
# content is   I really need to go to the hospital. I think smoking has finally taken it's effect on me.
#
# after line 412500 lexicon now has 998  words
# content is   ankle huurtss
#
# after line 415000 lexicon now has 1000  words
# content is   @camillaaxo aw whats wrong?
#
# after line 417500 lexicon now has 1006  words
# content is   what happened to Rob and Kristen's twitter?  ive only been away a couple of days...oooo soo sad
#
# after line 420000 lexicon now has 1012  words
# content is   it's the first week of june already and i can't think of a subject for my photoblog  i need to find inspiration fast! any suggestions?
#
# after line 422500 lexicon now has 1014  words
# content is   Ughhh my tummy
#
# after line 425000 lexicon now has 1017  words
# content is   hangover all gone now. Huzzah. Not looking forward to going to work tomorrow and being reminded what i did though
#
# after line 427500 lexicon now has 1023  words
# content is    LOL. that's really not funny though... I WANNA GO 2 CHURCH!!!
#
# after line 430000 lexicon now has 1025  words
# content is    i think this a-level may be a bit shite
#
# after line 432500 lexicon now has 1027  words
# content is   Ahnh! So tired! My Mommy's coming to get me at 12.
#
# after line 435000 lexicon now has 1032  words
# content is   @guytustin my party is moving to Sarasota  sad to have not met
#
# after line 437500 lexicon now has 1035  words
# content is   Am i going to miss BB tonight...
#
# after line 440000 lexicon now has 1039  words
# content is   @kreacheryl yes we are cause i bet you'd look better than me
#
# after line 442500 lexicon now has 1044  words
# content is   Oliver has thrashed me twice at Monopoly  glum times.
#
# after line 445000 lexicon now has 1046  words
# content is   @avrobro: no  it hurts so bad right now....please wait for me to get better!
#
# after line 447500 lexicon now has 1048  words
# content is   @hayley_rainbolt don't go to ny
#
# after line 450000 lexicon now has 1051  words
# content is    just feels dry all the time. wish it would go away...off to bed now
#
# after line 452500 lexicon now has 1061  words
# content is   Not needing to hear about the thunderstorm &amp; lightening strike during the European election count at dad's work. Not right now
#
# after line 455000 lexicon now has 1063  words
# content is   @JazzieSpazzy already dayum that sucks  lol
#
# after line 457500 lexicon now has 1064  words
# content is    very relaxing. Back to school tomorrow
#
# after line 460000 lexicon now has 1069  words
# content is   The doctor is late... Check will be in the afternoon instead of morning
#
# after line 462500 lexicon now has 1077  words
# content is   @itz_suziiie - waterbugs &amp; cockroaches bite! Check my away asap!!!  never go into the dungeon ever again!
#
# after line 465000 lexicon now has 1078  words
# content is   miss my honey
#
# after line 467500 lexicon now has 1080  words
# content is   I'm running out of money
#
# after line 470000 lexicon now has 1082  words
# content is   Walking home from am exam. Wishing i could see layla right now.
#
# after line 472500 lexicon now has 1085  words
# content is   Afraid this work week might be really painfull!!
#
# after line 475000 lexicon now has 1089  words
# content is   @some1s_sista man I'm with you on that one. I've been really sick all weekend and there is no rest for us Moms.
#
# after line 477500 lexicon now has 1092  words
# content is   I'm off-line until after we move.  see y'all soon!
#
# after line 480000 lexicon now has 1093  words
# content is    over 102
#
# after line 482500 lexicon now has 1102  words
# content is   anyone want to goto volleyball camp as me for theres only 4more days? bc im dieingggg and everyone else is.  pleaseeee HELP ME!!!!!!! lol
#
# after line 485000 lexicon now has 1106  words
# content is   @natalielealand ohhhhh  ok. well if you get it fixed check it out (Y)
#
# after line 487500 lexicon now has 1109  words
# content is   @EdwardsCreative @michaelkent I wanna play too...
#
# after line 490000 lexicon now has 1113  words
# content is   i am the worst daughter ever. no computer for the rest of the week. phone updates will be on though so @reply/text me.
#
# after line 492500 lexicon now has 1120  words
# content is   I think... I Miss my best buddy.  Got a little over 2 months before I get to see him again. Rawr. But on the bright side I like cookies.??
#
# after line 495000 lexicon now has 1124  words
# content is    My Cameo is 1/2 a second  [ T _ T ]
#
# after line 497500 lexicon now has 1126  words
# content is    but it was delayed and now it's 10:30pm
#
# after line 500000 lexicon now has 1128  words
# content is   @dolphinnancy sorry mommy  i miss you too!
#
# after line 502500 lexicon now has 1134  words
# content is   lookin at my cma fest pics for the jabillionth time today. cant get over some of the great and dissappointing things  had SO much fun!
#
# after line 505000 lexicon now has 1135  words
# content is    knees or ankles
#
# after line 507500 lexicon now has 1147  words
# content is   Gotta true the rear wheel on the Kestrel. Has FSA RD600's with hidden nipples! Have to remove the tire to get to nipples
#
# after line 510000 lexicon now has 1148  words
# content is   @serbellishious
#
# after line 512500 lexicon now has 1151  words
# content is    but Premium still == teh dead
#
# after line 515000 lexicon now has 1159  words
# content is   @tyroga goddam! goes to show that humans as a race have such a long way to go to overcome small-mindedness. makes me ashamed of people.
#
# after line 517500 lexicon now has 1162  words
# content is   Waiting on the train. It's taking forever!!!
#
# after line 520000 lexicon now has 1166  words
# content is   i can't see most blog updates that I follow on my dashboard.  why is that? i'm missing their post.
#
# after line 522500 lexicon now has 1168  words
# content is    Blondie &amp; jemaine
#
# after line 525000 lexicon now has 1170  words
# content is   is about to get on the plane to go back to the states
#
# after line 527500 lexicon now has 1176  words
# content is   Bought a new iPhone case since I probably won't be getting the new phone.  Damn AT&amp;T.
#
# after line 530000 lexicon now has 1177  words
# content is    and now my back hurts-
#
# after line 532500 lexicon now has 1185  words
# content is   @davidandstuff thanks. I'll check it out. trying out synergy now. really simple. i don't have key controls on the old macbook.
#
# after line 535000 lexicon now has 1193  words
# content is   All the Jeeves and Wooster epsiodes have been taken off YouTube.  Those were the politest comment threads in the world.
#
# after line 537500 lexicon now has 1195  words
# content is   Finally home from my sisters and I'm so tired
#
# after line 540000 lexicon now has 1200  words
# content is   My cousin needs to stop having indigestion!! He smells like eggs..
#
# after line 542500 lexicon now has 1201  words
# content is    I hope she's not really mad.
#
# after line 545000 lexicon now has 1203  words
# content is   @RunDaniRun Less than a day  It will only make me miss you more.
#
# after line 547500 lexicon now has 1208  words
# content is   @abbychang don't tell me!!!  I don't wanna know gahh treasure dookie! haha
#
# after line 550000 lexicon now has 1214  words
# content is   cont~d - while other laptops continue with Local and Internet Access....  annoying.
#
# after line 552500 lexicon now has 1217  words
# content is   @emmysays its gonna be rainy tomorrow  boooo
#
# after line 555000 lexicon now has 1220  words
# content is   @Nirjhor i never used lindows
#
# after line 557500 lexicon now has 1224  words
# content is   says hi to vic n intan. miss u guys!!
#
# after line 560000 lexicon now has 1228  words
# content is   is rly mad now  f'in updates gonna kill someone!
#
# after line 562500 lexicon now has 1232  words
# content is   @pipnstuff This thing is lovely!! Big sensor too. Pricey though
#
# after line 565000 lexicon now has 1235  words
# content is   Forgot my damned coffee at home this morning.
#
# after line 567500 lexicon now has 1237  words
# content is   @PinkTrees: your not very talkative tonight
#
# after line 570000 lexicon now has 1239  words
# content is    but went to bed at 3a my time instead
#
# after line 572500 lexicon now has 1239  words
# content is    where's the site i can see it ?
#
# after line 575000 lexicon now has 1244  words
# content is   laid down and sort of napped for a while. feel better. still have to pack half my room though
#
# after line 577500 lexicon now has 1250  words
# content is   Didn't make it to Sonic today. One of my kids badly misbehaved so I told him we couldn't go anymore.
#
# after line 580000 lexicon now has 1259  words
# content is   I want to go to a free acoustic FTSK set..  lmfao. but still @ Caitlins home from the mall I'll be home in a bout and hour maybe churchy?
#
# after line 582500 lexicon now has 1263  words
# content is    i'm go to yasmin harmoni for graduation.... hiks.... hiks...
#
# after line 585000 lexicon now has 1265  words
# content is   @shelzuluaga Shell is on twitter and no one told me  Hope your having fun while your away.
#
# after line 587500 lexicon now has 1274  words
# content is   I am so incredibly annoyed at the rain ruining my tv tonight-SYTYCD ruined by interference &amp; I'm a Celebrity preempted by weather reports
#
# after line 590000 lexicon now has 1275  words
# content is   have to leave on sunday
#
# after line 592500 lexicon now has 1277  words
# content is   AHH I don't wanna do this philosophy exam
#
# after line 595000 lexicon now has 1278  words
# content is   @brittanyphantom My phone is out of minutes.
#
# after line 597500 lexicon now has 1284  words
# content is   @Morgannnn__ yay!!!i realised the other day i can type while looking at the screen =D lol but so can heaps of other people  haha
#
# after line 600000 lexicon now has 1289  words
# content is   www.myspace.com/fashionisthenextcity    .... rreallllyyy wanntsss lostprophets tickets now
#
# after line 602500 lexicon now has 1295  words
# content is   THE DESK!  one of the under things that you like rest your feet on broke and was sticking out and POP
#
# after line 605000 lexicon now has 1298  words
# content is   sad...NHL is over and no NFL yet
#
# after line 607500 lexicon now has 1302  words
# content is    hope its not swine flu the lemsip caps are getting on top of it
#
# after line 610000 lexicon now has 1302  words
# content is    you're still awesome.
#
# after line 612500 lexicon now has 1308  words
# content is   The work drama continues for so long the popsicle I brought for a morning treat melted
#
# after line 615000 lexicon now has 1315  words
# content is   hopes that all ships going or coming out of North Korea are thoroughly searched. You can bet they have 'something' incriminating on them.
#
# after line 617500 lexicon now has 1316  words
# content is   Just woke up and i feel like shit
#
# after line 620000 lexicon now has 1319  words
# content is   @Randsum I know! It's near impossible to find one
#
# after line 622500 lexicon now has 1320  words
# content is   im being ganged up on
#
# after line 625000 lexicon now has 1322  words
# content is   Hey I'm not lame!
#
# after line 627500 lexicon now has 1322  words
# content is   I'm officially home and missing my man.
#
# after line 630000 lexicon now has 1323  words
# content is   finally got some sleep! Hallelujah! Now getting ready for work
#
# after line 632500 lexicon now has 1328  words
# content is   Awww..  Max and ashley got kicked off SYTYCD. ;-(
#
# after line 635000 lexicon now has 1332  words
# content is   @typicalnaloboy  boo  but you can see it on the days when you dont work! then you will be evil!  muhahaha
#
# after line 637500 lexicon now has 1334  words
# content is   How sad is it when your dog dances better than you do?
#
# after line 640000 lexicon now has 1336  words
# content is   is now thinking too much.. can't sleep
#
# after line 642500 lexicon now has 1336  words
# content is    not a very good combination...
#
# after line 645000 lexicon now has 1339  words
# content is   so cold outside i don't have a jacket and i'm wearing a vest top
#
# after line 647500 lexicon now has 1343  words
# content is   @PeterParker01_ only 14  but still neally 15
#
# after line 650000 lexicon now has 1343  words
# content is   I just want to sleep.
#
# after line 652500 lexicon now has 1350  words
# content is   what's the best measurement of your public transit system? check out those bus stops. sad face for lafayette
#
# after line 655000 lexicon now has 1354  words
# content is   @amberrrniiicole yeah! i know!  i'm gonna try and get out of it. i really want to see blg/nsn. ughh i'm dying without my phone. haha
#
# after line 657500 lexicon now has 1356  words
# content is   in my room watching the rain from my window __ feeling alone _ I wan't my sister!!!! now!
#
# after line 660000 lexicon now has 1356  words
# content is    btw) - i don't get it
#
# after line 662500 lexicon now has 1359  words
# content is   New iPhone is sitting at home not being tinkered with.
#
# after line 665000 lexicon now has 1361  words
# content is    I shed a few tears
#
# after line 667500 lexicon now has 1368  words
# content is   I have to work during @blakeypoo's b day party  the only solution? Take a few shots before work. See you guys at 11
#
# after line 670000 lexicon now has 1376  words
# content is   @glockchen @mikes90 nothing really...just refilled my cellphone...2 shorts...snacks...just useless stuff ...thats why I am so ashamed
#
# after line 672500 lexicon now has 1383  words
# content is   Apparently the last bits of code for Occurro! will be written while I have the flu.  I'm pretty sure a truck must have run me over today.
#
# after line 675000 lexicon now has 1391  words
# content is   @Lisa_Veronica Huumm...Revenge is sweeter than you ever were?? D I love that song...it makes me want to cry  hehe
#
# after line 677500 lexicon now has 1396  words
# content is   well i woke up at 4:13 WHY...well guess what there is frickin swallow birds outside my window here  damn them they are noisy
#
# after line 680000 lexicon now has 1406  words
# content is   @theincrowdblog u dont want to bee  im really drunk still nd probs embarassed myself really bad.. whoopss. sushi soon tho! &amp; no drunk lisa
#
# after line 682500 lexicon now has 1408  words
# content is   I have so many accessories for things that I forget what I have
#
# after line 685000 lexicon now has 1411  words
# content is   @luxebrown I think it took over my whole avatari don't see my pic
#
# after line 687500 lexicon now has 1413  words
# content is   wants something sweet.  FOOD! FOOD! (
#
# after line 690000 lexicon now has 1421  words
# content is   I can't help but think that Mosley's TV interview will only fuel the flames of the auguments   #formula1
#
# after line 692500 lexicon now has 1427  words
# content is   Disney Talk: RIP: Wayne Allwine  http://bit.ly/aV9x0 #inspiration
#
# after line 695000 lexicon now has 1433  words
# content is   In a lot of pain now. UHH I want these three weeks to go by fast! This Sucks. Looks like no NY for me.
#
# after line 697500 lexicon now has 1436  words
# content is   want to buy a new memory card
#
# after line 700000 lexicon now has 1438  words
# content is   @batgirl2285 don't get blowd up
#
# after line 702500 lexicon now has 1441  words
# content is   Missed ballet class for an entire week now...  Longing to go back!
#
# after line 705000 lexicon now has 1447  words
# content is   Bummer thought I was going to sell bag today and buy iPhone 3G. Guy was super late. So left.
#
# after line 707500 lexicon now has 1454  words
# content is   @curlylou87 awww hun!!! u boycottin the wombledon .... no nadal is so upsettin!!!!
#
# after line 710000 lexicon now has 1462  words
# content is    u wanna see Jr  im trying 2 come home for the 4th airlines tix are $500 gotta put on the puppy eyes
#
# after line 712500 lexicon now has 1472  words
# content is   I knew that someday my resistance to studying for tests would catch up to me. I hope I've learned my lesson. LEED AP exam...fail.
#
# after line 715000 lexicon now has 1479  words
# content is   i'm so not enjoying toronto right now .  ugly has weather .. A Night At The Roxbury is a CLASSIC movie tho. =]
#
# after line 717500 lexicon now has 1481  words
# content is   @Chad_W  i'm trying not to worry..
#
# after line 720000 lexicon now has 1493  words
# content is   HEY WOOT WE GOT A TWITTER TIFF! LOVE YA GIRL HAHA. going to do chores later  -HOLLY
#
# after line 722500 lexicon now has 1497  words
# content is   @philbridler  if it's any consolation @finkmoney agrees with you LOL
#
# after line 725000 lexicon now has 1503  words
# content is   OMG came home to a house smelling of GAS! My 2 year old must have left the stove on before we left for 4 1/2 hours! My 2 cats came 2 mind
#
# after line 727500 lexicon now has 1511  words
# content is   @thelocaltourist Seems like a disappointing logo and brand and atmosphere for a name that I think is pretty cool.
#
# after line 730000 lexicon now has 1517  words
# content is   Philip Blenkinsop is not such a famous photographer! i can barely find relevant info on him
#
# after line 732500 lexicon now has 1521  words
# content is   Wished... but i gues it aint gonna happen. ily
#
# after line 735000 lexicon now has 1522  words
# content is   Going to see my dad today! his might be his last Father's day
#
# after line 737500 lexicon now has 1523  words
# content is    i can't get more connection
#
# after line 740000 lexicon now has 1525  words
# content is    but now I won't be able to take them seriously ever again...thanks for that!
#
# after line 742500 lexicon now has 1526  words
# content is    mario beat me! damn
#
# after line 745000 lexicon now has 1530  words
# content is   make that 27...apparently we can't go until 220.  I'm dyinggggggg
#
# after line 747500 lexicon now has 1536  words
# content is   This night at this time 2 months ago I was in the Odyessy and P!nk just came on stage  I'd do anything to go back!
#
# after line 750000 lexicon now has 1541  words
# content is   Me against the clock  trying to make it to Ash's fitting
#
# after line 752500 lexicon now has 1546  words
# content is   @imnothatintoyou will u do mai laundry too? I has tew tonite  http://myloc.me/55rI
#
# after line 755000 lexicon now has 1547  words
# content is    and Aaden
#
# after line 757500 lexicon now has 1549  words
# content is   @madeofballoons Next week!
#
# after line 760000 lexicon now has 1554  words
# content is   Sooo my pic is no longer show on my Icon...  awww Twitter ... In classs hooray...
#
# after line 762500 lexicon now has 1558  words
# content is   9 hours before setting off to glasto isn't an ideal time to have a dodgy tummy.
#
# after line 765000 lexicon now has 1561  words
# content is   @backstreetboys - FLORIDA - you didn't come here last time  #bsb
#
# after line 767500 lexicon now has 1566  words
# content is   @africanewtonxx I know right  who knows.. it's like impossible that it just dissapeared :S? xxx
#
# after line 770000 lexicon now has 1568  words
# content is   @tclick    we will make you feel better #tweetup
#
# after line 772500 lexicon now has 1569  words
# content is   @gmn2121 sorry to hear that.
#
# after line 775000 lexicon now has 1574  words
# content is   really really really CAN NOT find my drivers license!  someone help me please!
#
# after line 777500 lexicon now has 1576  words
# content is   Half of me is gone!! Again!!  I don't like this.
#
# after line 780000 lexicon now has 1578  words
# content is   Just got stung by a scorpion!! What next?!
#
# after line 782500 lexicon now has 1587  words
# content is   they are destroying Cafe by the Ruin's gazebo (one of my most memorable places!) to put  up the cheap sogo motel
#
# after line 785000 lexicon now has 1589  words
# content is   excited for a movie date with hubby... but then he's coming late again.
#
# after line 787500 lexicon now has 1593  words
# content is   Uh....Having cold on summer is so very strong..
#
# after line 790000 lexicon now has 1595  words
# content is   Being angry in my car .. he just broke down ..
#
# after line 792500 lexicon now has 1595  words
# content is    not for me. Sorry.
#
# after line 795000 lexicon now has 1597  words
# content is   Had a dream about OU last night...gosh I'm homesick
#
# after line 797500 lexicon now has 1602  words
# content is   Shouldnt presribed eardrops make things better? Only making things worse for me
#
# after line 800000 lexicon now has 1607  words
# content is   @Eric_Urbane Sounds like a rival is flagging your ads. Not much you can do about that though
#
# after line 802500 lexicon now has 1614  words
# content is   @gwane and I'd go with either a nose ring or an eyebrow bar... In my opinion
#
# after line 805000 lexicon now has 1616  words
# content is   new day.... NEW TRACK!!!!
#
# after line 807500 lexicon now has 1621  words
# content is    what a wonderful day! Updating Krafty Blogs later...  x
#
# after line 810000 lexicon now has 1625  words
# content is   @zenaweist They could also tweet @BeccaRoberts
#
# after line 812500 lexicon now has 1628  words
# content is   Drank too much wine  headache tomorrow :-/
#
# after line 815000 lexicon now has 1632  words
# content is   has one more sales appointment and then going hiking... SWEET
#
# after line 817500 lexicon now has 1633  words
# content is    enjoy the weather man
#
# after line 820000 lexicon now has 1643  words
# content is   @Lamartian30 Pfft school is koo. I'm ranked 2nd in my Experimental Psychology class  lol heeey do u have time to peep a track?
#
# after line 822500 lexicon now has 1645  words
# content is    and tweeting.  Already did my workout today
#
# after line 825000 lexicon now has 1651  words
# content is   Teasing and Mack 1-0 are taking Vegas by storm with another night of troublesome fun
#
# after line 827500 lexicon now has 1654  words
# content is   @forrestfanatic Just an awesome evening with my BF.
#
# after line 830000 lexicon now has 1656  words
# content is   @TheEllenShow I saw a clip online!  good show!
#
# after line 832500 lexicon now has 1658  words
# content is   in melbourne babyyyyy
#
# after line 835000 lexicon now has 1659  words
# content is    and other times it's REALLY annoying!
#
# after line 837500 lexicon now has 1662  words
# content is    is the direction I'm headed for todays Breakkie
#
# after line 840000 lexicon now has 1663  words
# content is   is twittin' while my baby girl sleeps
#
# after line 842500 lexicon now has 1664  words
# content is    would you be able to burn the 3rd disc for me?
#
# after line 845000 lexicon now has 1664  words
# content is    hope ur well
#
# after line 847500 lexicon now has 1665  words
# content is   @acometonitsway you're lovely anyway.
#
# after line 850000 lexicon now has 1678  words
# content is   @cmozilo Act II set is pretty breath-taking -Love the reaction it's been getting- Rodolfo's doing a fab job- agreed-Thx for the feedback
#
# after line 852500 lexicon now has 1684  words
# content is   @lizzledelacruz lucky you actually...freezing cold and windy here in South Africa
#
# after line 855000 lexicon now has 1688  words
# content is   Thanks to all for your nice thoughts. It was a lot of work and even more fun! Come diving with me sometime! Need lessons?
#
# after line 857500 lexicon now has 1692  words
# content is    she is a hero of woman emancipation in indonesia
#
# after line 860000 lexicon now has 1694  words
# content is    but I think it will turn out okay!
#
# after line 862500 lexicon now has 1699  words
# content is   @lazyshoveldj A shower scene? Interesting to know. lol Thanks for the movie recommendation! Let me know if you watch other good ones
#
# after line 865000 lexicon now has 1700  words
# content is   Watching Family Guy in bed
#
# after line 867500 lexicon now has 1702  words
# content is   @Amargosa I'll volunteer to test it
#
# after line 870000 lexicon now has 1703  words
# content is   Signing up for Twitter
#
# after line 872500 lexicon now has 1709  words
# content is   Ordered the Green Eggs &amp; Ham. Just call me Dr. Suess
#
# after line 875000 lexicon now has 1713  words
# content is   @WalterFuckinLee my mom said to get your ass over here then
#
# after line 877500 lexicon now has 1714  words
# content is    I'd use it on everyone here to make us all feel fabulous
#
# after line 880000 lexicon now has 1715  words
# content is   drive ins are fun...just saying.
#
# after line 882500 lexicon now has 1717  words
# content is   Morning all out there in Tweetland.
#
# after line 885000 lexicon now has 1720  words
# content is    etc.  Best part - free!
#
# after line 887500 lexicon now has 1724  words
# content is   @ThisIsRobThomas Well I love that song..would have loved to have heard it
#
# after line 890000 lexicon now has 1726  words
# content is    reading and listening to tunes if you should want me you will have to ring me!!
#
# after line 892500 lexicon now has 1730  words
# content is   Watching 'She's the man' in bed  Its 123am &amp; I should be asleep!
#
# after line 895000 lexicon now has 1734  words
# content is   @stacyepps Thank you for having me and @anthony_y_tony  It was a pleasure
#
# after line 897500 lexicon now has 1741  words
# content is   @cecilhamilton *2 thumbs up* for Depeche Mode. They Rock
#
# after line 900000 lexicon now has 1741  words
# content is    hooray!
#
# after line 902500 lexicon now has 1745  words
# content is   I'm tired from walking my dog hmm maybe a quick snooze
#
# after line 905000 lexicon now has 1748  words
# content is   @SamStreet69 back to the lovely land of the north
#
# after line 907500 lexicon now has 1749  words
# content is    and... me! I'm honored!
#
# after line 910000 lexicon now has 1750  words
# content is    ate good food  satisfied
#
# after line 912500 lexicon now has 1757  words
# content is   In walmart getting a mothers day card with every other procrastinating guy in chattanooga  slim pickings but got a good one.
#
# after line 915000 lexicon now has 1760  words
# content is   @just_another_1 I love that we just get a little peek of your dimple
#
# after line 917500 lexicon now has 1763  words
# content is   @sarahnd for nearly a month!!  So exciting
#
# after line 920000 lexicon now has 1777  words
# content is   @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEEP OUT MY NEW HIT SINGLES WWW.MYSPACE.COM/IPSOHOT I DEF. WAT U IN THE VIDEO!!
#
# after line 922500 lexicon now has 1780  words
# content is   and pickle is helping me clean
#
# after line 925000 lexicon now has 1786  words
# content is   Happy Mama's Day !  do I get a GODmothers day gift... Lmao
#
# after line 927500 lexicon now has 1798  words
# content is   @thomasfiss i loveee taking nappss tooo!!! especially after schooll!!!!  i lovvvveee u thomassss &lt;3333 ur soo beautifull!! LMAOOO!
#
# after line 930000 lexicon now has 1802  words
# content is   @lovebscott enjoying some pasta from pizza hut and watching will &amp; grace
#
# after line 932500 lexicon now has 1805  words
# content is   3:30 pm..David will be here..
#
# after line 935000 lexicon now has 1806  words
# content is    see you on the flip side!
#
# after line 937500 lexicon now has 1808  words
# content is   Thinking of getting a tatoo
#
# after line 940000 lexicon now has 1809  words
# content is   just trying to find out how this Twitter-thing works
#
# after line 942500 lexicon now has 1812  words
# content is   so iPhones are no longer in short supply then @macdevnet?
#
# after line 945000 lexicon now has 1818  words
# ...
#
# after line 4480000 lexicon now has 2637  words
# content is   still aching after yestdy's board sesh.. off to Kilnsey for the first sport routes of the summer!  now where did I put that clip stick?
#
# after line 4482500 lexicon now has 2637  words
# content is    ore ?
#
# after line 4485000 lexicon now has 2637  words
# content is    I was getting pretty confused
#
# after line 4487500 lexicon now has 2637  words
# content is    dearest twits! Sorry for the minimal tweeting... I gotta take the bus this morning so I'm in the rush-mode!
#
# after line 4490000 lexicon now has 2637  words
# content is   wants ben and jerrys ice cream!
#
# after line 4492500 lexicon now has 2637  words
# content is    the word 'teh' has already been - so 'the' will probably be skipped..
#
# after line 4495000 lexicon now has 2637  words
# content is   @caitt2104 I love you too
#
# after line 4497500 lexicon now has 2637  words
# content is   @GabeAcevedo Thanks!
#
# after line 4500000 lexicon now has 2637  words
# content is    anyone interested in art follow me to see
#
# after line 4502500 lexicon now has 2637  words
# content is   Off to get Sims 3.
#
# after line 4505000 lexicon now has 2637  words
# content is   @NickBarnett I'm pretty good i guess (even though im only in high school)
#
# after line 4507500 lexicon now has 2637  words
# content is    Joey is so cute!  and u look so gorgeous!
#
# after line 4510000 lexicon now has 2637  words
# content is   watching paris hilton's my new bff. ahaha
#
# after line 4512500 lexicon now has 2637  words
# content is    reading
#
# after line 4515000 lexicon now has 2637  words
# content is   @Shuzshuz yea..most probably.
#
# after line 4517500 lexicon now has 2637  words
# content is   @Holly_Jane hay cutie  hows the little baby?
#
# after line 4520000 lexicon now has 2637  words
# content is   Checking my twitter! This is taking longer by the day...
#
# after line 4522500 lexicon now has 2637  words
# content is    JRuby is not affected
#
# after line 4525000 lexicon now has 2637  words
# content is   @michaelsheen This made me giggle. What an interesting thing to see. lol. I'm glad your Palace experience went well.
#
# after line 4527500 lexicon now has 2637  words
# content is   @glasswentsmash hahaha thx!!!!!!!! ur like the first one telling me that hahahah thaaaanks
#
# after line 4530000 lexicon now has 2637  words
# content is   @CaLyCo oh also I'm taking mine to the Columbus zoo Friday.Crossing fingers for good weather.
#
# after line 4532500 lexicon now has 2637  words
# content is   did a wired thing today. draw a smiley  in the last page of exam copy unconsciously.
#
# after line 4535000 lexicon now has 2637  words
# content is   @jennifersage I am liking your music tweets! JAMC big heart from me
#
# after line 4537500 lexicon now has 2637  words
# content is   thunderstorms
#
# after line 4540000 lexicon now has 2637  words
# content is   Yay headless machine running Mint.
#
# after line 4542500 lexicon now has 2637  words
# content is    finally
#
# after line 4545000 lexicon now has 2637  words
# content is   @fairy_Freia ÃÂ ÃÂ¼ÃÂµÃÂ½Ã? ÃÂµÃ?ÃÂÃÂ.
#
# after line 4547500 lexicon now has 2637  words
# content is   Lalala left school early yesterday. Senior cut day today... Senioritis at its best  haha
#
# after line 4550000 lexicon now has 2637  words
# content is   turning in in a little while.  just finished episode 21 of #TheHills. breakfast with my parents at Ikea in the morning!
#
# after line 4552500 lexicon now has 2637  words
# content is   work work today! whooooo there for the rest of the day! stop by!
#
# after line 4555000 lexicon now has 2637  words
# content is   interview today!
#
# after line 4557500 lexicon now has 2637  words
# content is    congratulations! I loooooooooove Stratford-Upon-Avon. Hope the weather was kind to you.
#
# after line 4560000 lexicon now has 2637  words
# content is    help me~!~!
#
# after line 4562500 lexicon now has 2637  words
# content is   @jadeleilani you got it babe
#
# after line 4565000 lexicon now has 2637  words
# content is   Check out my tasty (AND FREE) margarita!  http://twitpic.com/6pks1
#
# after line 4567500 lexicon now has 2637  words
# content is   satisfied i finally ate some sushi.. now relaxing watchin some movies
#
# after line 4570000 lexicon now has 2637  words
# content is   @chantalclaret http://twitpic.com/6pury - That is a beautiful pic! Love the shoe in it
#
# after line 4572500 lexicon now has 2637  words
# content is   Noodles! Yumm!  http://mypict.me/2Lba
#
# after line 4575000 lexicon now has 2637  words
# content is   Watching tracy byrd. Life is awesome. Oh Yea
#
# after line 4577500 lexicon now has 2637  words
# content is   is excited that she finally got her sisters to agree to move back to GA with her next summer!!!
#
# after line 4580000 lexicon now has 2637  words
# content is   @x3heeeykaaate whoaaa you gotta interview!!  they never contacted me back :| how was it tho???
#
# after line 4582500 lexicon now has 2637  words
# content is   @Subreet  how are you?
#
# after line 4585000 lexicon now has 2637  words
# content is   @mandieluvsu love you friend! glad we got to dance it up tonight!
#
# after line 4587500 lexicon now has 2637  words
# content is   @celestialpoet I'm thinking I'll watch The Devil Wears Prada next
#
# after line 4590000 lexicon now has 2637  words
# content is   @SquishMitten hmmm its just not the same as 3 shredded wheat tho
#
# after line 4592500 lexicon now has 2637  words
# content is   @VioletLily watch Donnie Darko or Life as a house.
#
# after line 4595000 lexicon now has 2637  words
# content is    tweeties.
#
# after line 4597500 lexicon now has 2637  words
# content is   @slapthemartian adviser nila?
#
# after line 4600000 lexicon now has 2637  words
# content is   Bout to get ready and go watch my nieces ballet recital  she's too cute
#
# after line 4602500 lexicon now has 2637  words
# content is   @resideo Excited to see what's in store.  Welcome back!
#
# after line 4605000 lexicon now has 2637  words
# content is    today is my birthday!
#
# after line 4607500 lexicon now has 2637  words
# content is   excited for today's festivities
#
# after line 4610000 lexicon now has 2637  words
# content is   Having so many ideas today. If I can just put manners on them they'll be fantastic. The creative juices are flowing again. Hurrah
#
# after line 4612500 lexicon now has 2637  words
# content is   The Royal Pains pilot was amazing. Looks like it's going to be a great show.
#
# after line 4615000 lexicon now has 2637  words
# content is   @ddlovaato http://twitpic.com/6fe11 - no!!!!!!!!!!!!! i love DEMI so much (more more more more  more more than you clau)  &quot;bueno por i ...
#
# after line 4617500 lexicon now has 2637  words
# content is   A lot of food today !!  http://is.gd/QAsP
#
# after line 4620000 lexicon now has 2637  words
# content is   outside around the pool on the laptop. hope it doesn't fall in the water
#
# after line 4622500 lexicon now has 2637  words
# content is   just got out of gorging myself at Outback... now to the camera shop! today is just beautiful...and im making my bucket list
#
# after line 4625000 lexicon now has 2637  words
# content is    but it's my absolute favorite!!
#
# after line 4627500 lexicon now has 2637  words
# content is    u know your following your spirit...do it
#
# after line 4630000 lexicon now has 2637  words
# content is    looks like I'm working late. We close around 12 &amp; it's about 9ish. I'll hop online as soon as I can when I get home
#
# after line 4632500 lexicon now has 2637  words
# content is    depending on how much time I have every day.
#
# after line 4635000 lexicon now has 2637  words
# content is   game starting.  go sounders.
#
# after line 4637500 lexicon now has 2637  words
# content is   SBA. greatest thing ever. tonight was amzing
#
# after line 4640000 lexicon now has 2637  words
# content is   ^b
#
# after line 4642500 lexicon now has 2637  words
# content is   @McCainBlogette love this about you Meghan :] keep it real and be yourself! love you
#
# after line 4645000 lexicon now has 2637  words
# content is    leaving now to drink wit a few people
#
# after line 4647500 lexicon now has 2637  words
# content is    I'm ok  you?
#
# after line 4650000 lexicon now has 2637  words
# content is   @Amihama Well when the game is released you'll have your chance!
#
# after line 4652500 lexicon now has 2637  words
# content is   A-N-N-O-Y-I-N-G &amp; LOVELY Monkey
#
# after line 4655000 lexicon now has 2637  words
# content is   The Lakers need to protect their House ... Go Lakers can you tell i'm excited about this
#
# after line 4657500 lexicon now has 2637  words
# content is   @sonyasison haha you're full of corniness Sonya!!! that's why I love you ha ha ha ha ha.. I think I am!! things have been healing quick!
#
# after line 4660000 lexicon now has 2637  words
# content is   @amberkimberley Do you know Groveshark? I love this site for listening to music http://listen.grooveshark.com/
#
# after line 4662500 lexicon now has 2637  words
# content is    I had no money on my card. haha and I'm not going to be near a EzyDVD till after the sale. Oh well shit happens
#
# after line 4665000 lexicon now has 2637  words
# content is   @feblub thank you
#
# after line 4667500 lexicon now has 2637  words
# content is   @sharlynnx i still think your amazing  haha x
#
# after line 4670000 lexicon now has 2637  words
# content is    yes! Elisa`s the name and you`re Ning! Isn`t it annoying when people use their Tumblrs as guestbooks? Random! Haha
#
# after line 4672500 lexicon now has 2637  words
# content is   @urbanfly Solid work!
#
# after line 4675000 lexicon now has 2637  words
# content is   @cpembleton but you are too! I did not know that tool existed.
#
# after line 4677500 lexicon now has 2637  words
# content is   @aravindkumar @seer thanks man  I took the pics using my Sony Ericsson Mobile 2MP camera... yeah believe it
#
# after line 4680000 lexicon now has 2637  words
# content is    now going to watch the Prefontaine Track Classic! Have a great Sunday everyone!
#
# after line 4682500 lexicon now has 2637  words
# content is   @spcoates Lol thanks for the lovely mention!  I remember that day whilst crossing the road: 'You've a lovely complexion today'! xxx
#
# after line 4685000 lexicon now has 2637  words
# content is   being completely worthless today...laying on the couch and enjoying my existence...and Mat Kearney's new album
#
# after line 4687500 lexicon now has 2637  words
# content is   What are you all up to? Great weather your way I hope!
#
# after line 4690000 lexicon now has 2637  words
# content is    powerplay
#
# after line 4692500 lexicon now has 2637  words
# content is   Batman movie marathon. All in good fun  haha summer is awesome when you get creative.
#
# after line 4695000 lexicon now has 2637  words
# content is   GoGoGo... move up by 1  24. tribbleagency.com
#
# after line 4697500 lexicon now has 2637  words
# content is   @mitchelmusso http://twitpic.com/6uv4f - The jobros don't even have this yet!! haha luv u and jb!!!
#
# after line 4700000 lexicon now has 2637  words
# content is   @heycassadee Can I ask a question?
#
# after line 4702500 lexicon now has 2637  words
# content is   Say a preview for there will be blood. That was a good one
#
# after line 4705000 lexicon now has 2637  words
# content is    this one was shorter. Had a good time.
#
# after line 4707500 lexicon now has 2637  words
# content is   @CarlMaxx thank you
#
# after line 4710000 lexicon now has 2637  words
# content is    maybe uffizi.
#
# after line 4712500 lexicon now has 2637  words
# content is   Off to bed early tonight Whoo! Im still excited about the Lakers. NBA Championships yall!  They truly deserve it.
#
# after line 4715000 lexicon now has 2637  words
# content is   @georgiibeatle you should totally come to see britney in november with me
#
# after line 4717500 lexicon now has 2637  words
# content is   @KahleeRose is there anything you cannot acronymise?
#
# after line 4720000 lexicon now has 2637  words
# content is   any shops here we could try get GK in?
#
# after line 4722500 lexicon now has 2637  words
# content is   I do not enjoy humidity. Phone will be off all day. Don't miss me as much as i'll miss you guys. Jesus loves you!
#
# after line 4725000 lexicon now has 2637  words
# content is   @smellyyy yes i agree .... fcuk religion  fcuk miss  GIRLLLSS... LADDIEESS
#
# after line 4727500 lexicon now has 2637  words
# content is   OMG! Thank u tom joyner! &quot;Motown Philly..&quot;. Just what u needed! Nothing could mess up my day
#
# after line 4730000 lexicon now has 2637  words
# content is   @markmillergroup Hi! Let me know if you need help! Welcome to Twitter
#
# after line 4732500 lexicon now has 2637  words
# content is   @ WORK UNTIL 3pm &gt;&gt;&gt;&gt;&gt; THEN CASINO LATER UMMM WAT SHOULD I WEAR
#
# after line 4735000 lexicon now has 2637  words
# content is   @dashabbfan Good Luck!  I know you can do it!
#
# after line 4737500 lexicon now has 2637  words
# content is   @ComedyQueen *I wish i may i wish i might that i may get my wish tonight*
#
# after line 4740000 lexicon now has 2637  words
# content is   Oh so many decisions...feel like my head is gonna blow!
#
# after line 4742500 lexicon now has 2637  words
# content is   Amazing weather today! Thank you sun!
#
# after line 4745000 lexicon now has 2637  words
# content is   @jsbond good luck! May the force be with you
#
# after line 4747500 lexicon now has 2637  words
# content is   @ptthe13 mas a les paul ia-te ficar bem
#
# after line 4750000 lexicon now has 2637  words
# content is   @gley10 get on aim?
#
# after line 4752500 lexicon now has 2637  words
# content is   Smiling from the inside out!!!!
#
# after line 4755000 lexicon now has 2637  words
# content is   Just bought so much stuff from cvs... 3D SIDEWALK CHALK
#
# after line 4757500 lexicon now has 2637  words
# content is    I'm a best friend
#
# after line 4760000 lexicon now has 2637  words
# content is   @miafreedman i had a friend that bagged it until she read it just recently and loved it. Just try it and then see what you think
#
# after line 4762500 lexicon now has 2637  words
# content is    suckers... Notice a theme  Somehow it worked for DP!
#
# after line 4765000 lexicon now has 2637  words
# content is    that tweet of mine sounded way wrong otherwise.
#
# after line 4767500 lexicon now has 2637  words
# content is    i wish i would remember that more often
#
# after line 4770000 lexicon now has 2637  words
# content is   @TechWraith Waitaminute. How did you lose it? It was obviously an oversight on my part
#
# after line 4772500 lexicon now has 2637  words
# content is   My favorite part of the night...@prissi2 said wait I think I just saw Jonas on the Burger King window...go back go back!! Haha hilarious!
#
# after line 4775000 lexicon now has 2637  words
# content is   thanks for all the book recs! i think that's enough to add to the list for summer
#
# after line 4777500 lexicon now has 2637  words
# content is   this will help lots  #jtv http://justin.tv/scotsmanstuart
#
# after line 4780000 lexicon now has 2637  words
# content is   Long ass night at work- but a good ending  finally home
#
# after line 4782500 lexicon now has 2637  words
# content is   yay finished exams for this semester!!
#
# after line 4785000 lexicon now has 2637  words
# content is    when all I really need is a break for some WoW or MTGO action
#
# after line 4787500 lexicon now has 2637  words
# content is    i know what you mean. I am still looking to get a Point with doctrine to calculate proximity
#
# after line 4790000 lexicon now has 2637  words
# content is   ahh another relaxing day sunbathing then heading down to the hairdressers for some tlc lovely.
#
# after line 4792500 lexicon now has 2637  words
# content is   @rebeccawatson have you tried this?  http://bit.ly/xPU6k even though it's not YOUR city per se
#
# after line 4795000 lexicon now has 2637  words
# content is   @give_me_RAWRRR  what lesson do you have next?
#
# after line 4797500 lexicon now has 2637  words
# content is   Wow. Koenigsegg bought Saab. They have less than 50 employees  But they sure do make awesome supercars!
#
# after line 4800000 lexicon now has 2637  words
# content is   Happy 38th Birthday to my boo of alll time!!! Tupac Amaru Shakur

# %%
def convert_to_vec(fin,fout,lexicon_pickle):
    with open(lexicon_pickle,'rb') as f:
        lexicon = pickle.load(f)
    outfile = open(fout,'a')
    with open(fin, buffering=20000, encoding='latin-1') as f:
        counter = 0
        for line in f:
            counter +=1
            label = line.split(':::')[0]
            tweet = line.split(':::')[1]
            current_words = word_tokenize(tweet.lower())
            current_words = [lemmatizer.lemmatize(i) for i in current_words]

            features = np.zeros(len(lexicon))

            for word in current_words:
                if word.lower() in lexicon:
                    index_value = lexicon.index(word.lower())
                    # OR DO +=1, test both
                    features[index_value] += 1

            features = list(features)
            outline = str(features)+'::'+str(label)+'\n'
            outfile.write(outline)

        print(counter)

# %%
convert_to_vec('test_set.csv','processed-test-set.csv','lexicon-2500-2638.pickle')

# %%
def shuffle_data(fin):
    df = pd.read_csv(fin, error_bad_lines=False)
    df = df.iloc[np.random.permutation(len(df))]
    print(df.head())
    df.to_csv('train_set_shuffled.csv', index=False)

# %%
shuffle_data('train_set.csv')

# %%
def create_test_data_pickle(fin): # what is the purpose of this function... it doesn't ouput anything?

    feature_sets = []
    labels = []
    counter = 0
    with open(fin, buffering=20000) as f:
        for line in f:
            try:
                features = list(eval(line.split(':::')[1])) # shouldn't it be ':::'?
                label = list(eval(line.split(':::')[0]))

                feature_sets.append(features)
                labels.append(label)
                counter += 1
            except:
                pass
    print(counter)
    feature_sets = np.array(feature_sets)
    labels = np.array(labels)
# Out:
# 0

# %%
create_test_data_pickle('processed-test-set.csv')
